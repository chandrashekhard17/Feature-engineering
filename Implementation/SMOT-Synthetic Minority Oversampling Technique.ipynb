# %% [markdown]
# #SMOT

# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=1000,n_features=2,n_clusters_per_class=1,n_redundant=0,weights=[0.90],random_state=12)

# %%
import pandas as pd
df1=pd.DataFrame(x,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df2],axis=1)

# %%
final_df['target'].value_counts()
# Out:
# 0    900
# 1    100
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'],)

# %%
pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\chand\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\chand\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\chand\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\chand\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\chand\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.23.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\chand\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\chand\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample=SMOTE()

# %%
x,y=oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
x.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(x[x==0])
# Out:
# 1800

# %%
len(y[y==1])
# Out:
# 900

# %%
df1=pd.DataFrame(x,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
oversample_df=pd.concat([df1,df2],axis=1)

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])

# %%
#This changes from first visualisation to the last visualisation
