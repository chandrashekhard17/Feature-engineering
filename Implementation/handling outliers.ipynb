# %% [raw]
# #minimum , maximum , median, q1,q3

# %%
import numpy as np

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (32.0, 54.0, 67.0, 89.0, 99.0)

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 35.0

# %%
lower_fence=Q1-(1.5*IQR)
higher_fence=Q3+(1.5*IQR)

# %%
lower_fence,higher_fence
# Out:
# (1.5, 141.5)

# %%
outliers=[x for x in lst_marks if x < lower_fence or x > higher_fence]

# %%
outliers
#there is no element of outliers
# Out:
# []

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(lst_marks)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e5369425c0>,
#   <matplotlib.lines.Line2D at 0x2e536942860>],
#  'caps': [<matplotlib.lines.Line2D at 0x2e536942b00>,
#   <matplotlib.lines.Line2D at 0x2e536942da0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2e536942320>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e536943040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e5369432e0>],
#  'means': []}

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,180]

# %%
outliers=[x for x in lst_marks if x < lower_fence or x > higher_fence]

# %%
outliers
# Out:
# [-100, -200, 150, 170, 180]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
plt.boxplot(lst_marks)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2e53ade01c0>,
#   <matplotlib.lines.Line2D at 0x2e53ade0550>],
#  'caps': [<matplotlib.lines.Line2D at 0x2e53ade07f0>,
#   <matplotlib.lines.Line2D at 0x2e53ade0070>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2e53ade0910>],
#  'medians': [<matplotlib.lines.Line2D at 0x2e53ade0df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2e53a73a0b0>],
#  'means': []}
